# %%
import requests
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
response=requests.get("https://api.themoviedb.org/3/movie/popular?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1").json()

# %%
popu=[]
vote_count=[]
title=[]
original_language=[]
vote_average=[]
overview=[]
release=[]

for i in response['results']:
    popu.append(i['popularity'])
    vote_count.append(i['vote_count'])
    title.append(i['title'])
    original_language.append(i["original_language"])
    overview.append(i["overview"])
    release.append(i['release_date'])
    vote_average.append(i["vote_average"])
d={'title':title,'overview':overview,'release_date':release,'popularity':popu,"vote_count":vote_count,"vote_average":vote_average,"original_language":original_language}
dw=pd.DataFrame(d)
print(dw)
# Out:
#                                   title  \
# 0                             Elemental
# 1                        Heart of Stone
# 2                     Meg 2: The Trench
# 3   Spider-Man: Across the Spider-Verse
# 4      Transformers: Rise of the Beasts
# 5                                Barbie
# 6                             The Flash
# 7              Babylon 5: The Road Home
# 8                      No Hard Feelings
# 9                                Cobweb
# 10                            The Flood
# 11              Kingdom 2: Far and Away
# 12                               Fast X
# 13                          Soulcatcher
# 14              Insidious: The Red Door
# 15                               Dampyr
# 16                        Hidden Strike
# 17       Guardians of the Galaxy Vol. 3
# 18                           Talk to Me
# 19                   The Little Mermaid
#
#                                              overview release_date  \
# 0   In a city where fire, water, land and air resi...   2023-06-14
# 1   An intelligence operative for a shadowy global...   2023-08-09
# 2   An exploratory dive into the deepest depths of...   2023-08-02
# 3   After reuniting with Gwen Stacy, Brooklyn’s fu...   2023-05-31
# 4   When a new threat capable of destroying the en...   2023-06-06
# 5   Barbie and Ken are having the time of their li...   2023-07-19
# 6   When his attempt to save his family inadverten...   2023-06-13
# 7   Travel across the galaxy with John Sheridan as...   2023-08-15
# 8   On the brink of losing her childhood home, Mad...   2023-06-15
# 9   Eight year old Peter is plagued by a mysteriou...   2023-07-19
# 10  A horde of giant hungry alligators is unleashe...   2023-07-14
# 11  It follows a young man who dreams of becoming ...   2022-07-15
# 12  Over many missions and against impossible odds...   2023-05-17
# 13  A military contractor hired to seize a weapon ...   2023-08-02
# 14  To put their demons to rest once and for all, ...   2023-07-05
# 15  Haunted by nightmares, con artist Harlan Draka...   2022-10-28
# 16  Two elite soldiers must escort civilians throu...   2023-07-06
# 17  Peter Quill, still reeling from the loss of Ga...   2023-05-03
# 18  When a group of friends discover how to conjur...   2023-07-26
# 19  The youngest of King Triton’s daughters, and t...   2023-05-18
#
#     popularity  vote_count  vote_average original_language
# 0     3167.104        1452           7.8                en
# 1     2650.154         800           6.9                en
# 2     2319.709         724           7.0                en
# 3     2044.250        3775           8.4                en
# 4     1646.070        2947           7.5                en
# 5     1659.364        3404           7.4                en
# 6     1554.403        2521           7.0                en
# 7     1411.884          36           7.2                en
# 8     1236.409         910           7.1                en
# 9     1290.472         221           6.7                en
# 10    1166.779         167           6.9                en
# 11    1157.664          22           7.0                ja
# 12    1191.399        3487           7.3                en
# 13    1015.950         145           6.6                pl
# 14     989.245         969           6.9                en
# 15     856.533          60           6.7                it
# 16     814.469         635           7.1                en
# 17     797.597        4502           8.0                en
# 18     821.407         244           7.1                en
# 19     777.475        1706           6.6                en

# %%
final=pd.DataFrame()
for j in range(0,10):
    reponse=requests.get("https://api.themoviedb.org/3/movie/popular?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={}".format(j)).json()
    popu=[]
    vote_count=[]
    title=[]
    original_language=[]
    vote_average=[]
    overview=[]
    release=[]

    for i in response['results']:
        popu.append(i['popularity'])
        vote_count.append(i['vote_count'])
        title.append(i['title'])
        original_language.append(i["original_language"])
        overview.append(i["overview"])
        release.append(i['release_date'])
        vote_average.append(i["vote_average"])
    d={'title':title,'overview':overview,'release_date':release,'popularity':popu,"vote_count":vote_count,"vote_average":vote_average,"original_language":original_language}
    df=pd.DataFrame(d)
    final=final.append(df,ignore_index=True)

# %%
final
# Out:
#                                    title  \
# 0                              Elemental
# 1                         Heart of Stone
# 2                      Meg 2: The Trench
# 3    Spider-Man: Across the Spider-Verse
# 4       Transformers: Rise of the Beasts
# ..                                   ...
# 195                               Dampyr
# 196                        Hidden Strike
# 197       Guardians of the Galaxy Vol. 3
# 198                           Talk to Me
# 199                   The Little Mermaid
#
#                                               overview release_date  \
# 0    In a city where fire, water, land and air resi...   2023-06-14
# 1    An intelligence operative for a shadowy global...   2023-08-09
# 2    An exploratory dive into the deepest depths of...   2023-08-02
# 3    After reuniting with Gwen Stacy, Brooklyn’s fu...   2023-05-31
# 4    When a new threat capable of destroying the en...   2023-06-06
# ..                                                 ...          ...
# 195  Haunted by nightmares, con artist Harlan Draka...   2022-10-28
# 196  Two elite soldiers must escort civilians throu...   2023-07-06
# 197  Peter Quill, still reeling from the loss of Ga...   2023-05-03
# 198  When a group of friends discover how to conjur...   2023-07-26
# 199  The youngest of King Triton’s daughters, and t...   2023-05-18
#
#      popularity  vote_count  vote_average original_language
# 0      3167.104        1452           7.8                en
# 1      2650.154         800           6.9                en
# 2      2319.709         724           7.0                en
# 3      2044.250        3775           8.4                en
# 4      1646.070        2947           7.5                en
# ..          ...         ...           ...               ...
# 195     856.533          60           6.7                it
# 196     814.469         635           7.1                en
# 197     797.597        4502           8.0                en
# 198     821.407         244           7.1                en
# 199     777.475        1706           6.6                en
#
# [200 rows x 7 columns]

# %%
final.to_csv('movies.csv')
