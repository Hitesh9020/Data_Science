# %% [markdown]
# Aim: Perform Data Wrangling: implementing the following operations using Python (Pandas)

# %% [markdown]
# Problem statemeng: Data Wrangling  Perform the following operations using Python on any open source dataset (eg. data.csv)

# %% [markdown]
# -->

# %% [markdown]
# Import all the required Python Libraries.

# %%
import pandas as pd

# %% [markdown]
# Locate an open source data from the web (eg. https://www.kaggle.com). Provide a clear description of the data and its source (i.e. URL of the web site).

# %%
dataset=pd.read_csv("/content/titanic.csv")

# %% [markdown]
# Load the Dataset into pandas dataframe.

# %%
dataset=pd.read_csv("/content/titanic.csv")
data_frame=pd.DataFrame(data=dataset)
data_frame
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# Data Preprocessing:

# %% [markdown]
# Missing Values in the Dataset are as follows:

# %%
print("The Total Missing Values in the Dataset:\n",data_frame.isnull().sum())
# Out:
# The Total Missing Values in the Dataset:
#  PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# Basic Statistics data of the Dataset

# %%
data_frame.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
data_frame.shape
# Out:
# (891, 12)

# %%
data_frame.size
# Out:
# 10692

# %%
data_frame.ndim
# Out:
# 2

# %%
data_frame.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# Slicing the columns of the dataset

# %%
data_frame.iloc[:,[0,2,-1]]
# Out:
#      PassengerId  Pclass Embarked
# 0              1       3        S
# 1              2       1        C
# 2              3       3        S
# 3              4       1        S
# 4              5       3        S
# ..           ...     ...      ...
# 886          887       2        S
# 887          888       1        S
# 888          889       3        S
# 889          890       1        C
# 890          891       3        Q
#
# [891 rows x 3 columns]

# %% [markdown]
# Displaying the Top 10 rows of the dataset using head() function

# %%
data_frame.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %% [markdown]
# Displaying the Bottom 10 rows of the dataset using tail() function

# %%
data_frame.tail(10)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %% [markdown]
# Checking the condition and displaying the output accordingly (female in sex column)

# %%
data_frame.loc[data_frame['Sex']=="female"]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 880          881         1       2
# 882          883         0       3
# 885          886         0       3
# 887          888         1       1
# 888          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# Displaying "Ticket" column details

# %%
data_frame["Ticket"]
# Out:
# 0             A/5 21171
# 1              PC 17599
# 2      STON/O2. 3101282
# 3                113803
# 4                373450
#              ...
# 886              211536
# 887              112053
# 888          W./C. 6607
# 889              111369
# 890              370376
# Name: Ticket, Length: 891, dtype: object

# %% [markdown]
# Displaying up the top rows of the dataset with their columns.
#
# Displaying the number of rows randomly.
#
# Slicing the rows.

# %% [markdown]
#  Displaying only specific columns.

# %%
data_frame.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# Displaying the numbers of rows

# %%
data_frame.sample(10)
# Out:
#      PassengerId  Survived  Pclass  \
# 308          309         0       2
# 210          211         0       3
# 721          722         0       3
# 649          650         1       3
# 580          581         1       2
# 567          568         0       3
# 549          550         1       2
# 88            89         1       1
# 591          592         1       1
# 581          582         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 308                                Abelson, Mr. Samuel    male  30.0      1
# 210                                     Ali, Mr. Ahmed    male  24.0      0
# 721                          Jensen, Mr. Svend Lauritz    male  17.0      1
# 649                    Stanley, Miss. Amy Zillah Elsie  female  23.0      0
# 580                        Christy, Miss. Julie Rachel  female  25.0      1
# 567        Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# ...

# %% [markdown]
# Slicicng the rows

# %%
data_frame.iloc[1:5,1:6]
# Out:
#    Survived  Pclass                                               Name  \
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age
# 1  female  38.0
# 2  female  26.0
# 3  female  35.0
# 4    male  35.0

# %%
data_frame.iloc[:,[0,1,-1]]
# Out:
#      PassengerId  Survived Embarked
# 0              1         0        S
# 1              2         1        C
# 2              3         1        S
# 3              4         1        S
# 4              5         0        S
# ..           ...       ...      ...
# 886          887         0        S
# 887          888         1        S
# 888          889         0        S
# 889          890         1        C
# 890          891         0        Q
#
# [891 rows x 3 columns]

# %% [markdown]
# Summarize the types of variables by checking the data types (i.e., character, numeric, integer, factor, and logical) of the variables in the data set.

# %%
data_frame.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# Here,
#
# Character: Name,Sex,Ticket,Cabin,Embarked
#
# Numeric: PassengerId, Survived, Pclass, Sibsp, Parch
#
# Factor: Age, Fare

# %% [markdown]
# Explain every operation that you do in the above steps and explain everything that you do to import/read/scrape the data set

# %% [markdown]
#  I have imported two libraries pandas,numpy.
#
#  For reading csv file i used  *pd.csv_read("")*  and then converted it into dataframe using "pd.DataFrame".

# %% [markdown]
# Conclusion:
#
# 1.   Imported libarires and then read csv file
# 2.  Described all details about data
