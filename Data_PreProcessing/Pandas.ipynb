# %%
# Importing pandas 
import pandas as pd
df = pd.read_csv("pokemon.csv")   # Reading csv file through pandas
df.head()  # top 5 columns of dataset
# Out:
#    Unnamed: 0  #                   Name Type 1  Type 2  Total  HP  Attack  \
# 0           0  1              Bulbasaur  Grass  Poison    318  45      49
# 1           1  2                Ivysaur  Grass  Poison    405  60      62
# 2           2  3               Venusaur  Grass  Poison    525  80      82
# 3           3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100
# 4           4  4             Charmander   Fire     NaN    309  39      52
#
#    Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       49       65       65     45           1      False
# 1       63       80       80     60           1      False
# 2       83      100      100     80           1      False
# 3      123      122      120     80           1      False
# 4       43       60       50     65           1      False

# %%
df.columns   # Read Headers
# Out:
# Index(['Unnamed: 0', '#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack',
#        'Defense', 'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
df[['Name','Type 1','HP']]   # Specific column
# Out:
#                       Name   Type 1  HP
# 0                Bulbasaur    Grass  45
# 1                  Ivysaur    Grass  60
# 2                 Venusaur    Grass  80
# 3    VenusaurMega Venusaur    Grass  80
# 4               Charmander     Fire  39
# ..                     ...      ...  ..
# 795                Diancie     Rock  50
# 796    DiancieMega Diancie     Rock  50
# 797    HoopaHoopa Confined  Psychic  80
# 798     HoopaHoopa Unbound  Psychic  80
# 799              Volcanion     Fire  80
#
# [800 rows x 3 columns]

# %%
df.iloc[:,0:5]   # indexing with pandas
# Out:
#      Unnamed: 0    #                   Name   Type 1  Type 2
# 0             0    1              Bulbasaur    Grass  Poison
# 1             1    2                Ivysaur    Grass  Poison
# 2             2    3               Venusaur    Grass  Poison
# 3             3    3  VenusaurMega Venusaur    Grass  Poison
# 4             4    4             Charmander     Fire     NaN
# ..          ...  ...                    ...      ...     ...
# 795         795  719                Diancie     Rock   Fairy
# 796         796  719    DiancieMega Diancie     Rock   Fairy
# 797         797  720    HoopaHoopa Confined  Psychic   Ghost
# 798         798  720     HoopaHoopa Unbound  Psychic    Dark
# 799         799  721              Volcanion     Fire   Water
#
# [800 rows x 5 columns]

# %%
for index,row in df.iterrows():   # one by one data with their characteristic
    print(index,row)
# Out:
# 0 Unnamed: 0            0
# #                     1
# Name          Bulbasaur
# Type 1            Grass
# Type 2           Poison
# Total               318
# HP                   45
# Attack               49
# Defense              49
# Sp. Atk              65
# Sp. Def              65
# Speed                45
# Generation            1
# Legendary         False
# Name: 0, dtype: object
# 1 Unnamed: 0          1
# #                   2
# Name          Ivysaur
# Type 1          Grass
# Type 2         Poison
# Total             405
# HP                 60
# Attack             62
# Defense            63
# Sp. Atk            80
# Sp. Def            80
# Speed              60
# Generation          1
# Legendary       False
# Name: 1, dtype: object
# 2 Unnamed: 0           2
# #                    3
# Name          Venusaur
# Type 1           Grass
# Type 2          Poison
# Total              525
# HP                  80
# Attack              82
# Defense             83
# ...

# %%
df.loc[df['Type 1']=='Fire']  # filtering data
# Out:
#      Unnamed: 0    #                       Name Type 1    Type 2  Total   HP  \
# 4             4    4                 Charmander   Fire       NaN    309   39
# 5             5    5                 Charmeleon   Fire       NaN    405   58
# 6             6    6                  Charizard   Fire    Flying    534   78
# 7             7    6  CharizardMega Charizard X   Fire    Dragon    634   78
# 8             8    6  CharizardMega Charizard Y   Fire    Flying    634   78
# 42           42   37                     Vulpix   Fire       NaN    299   38
# 43           43   38                  Ninetales   Fire       NaN    505   73
# 63           63   58                  Growlithe   Fire       NaN    350   55
# 64           64   59                   Arcanine   Fire       NaN    555   90
# 83           83   77                     Ponyta   Fire       NaN    410   50
# 84           84   78                   Rapidash   Fire       NaN    500   65
# ...

# %%
df.describe()
# Out:
#        Unnamed: 0           #      Total          HP      Attack     Defense  \
# count    800.0000  800.000000  800.00000  800.000000  800.000000  800.000000
# mean     399.5000  362.813750  435.10250   69.258750   79.001250   73.842500
# std      231.0844  208.343798  119.96304   25.534669   32.457366   31.183501
# min        0.0000    1.000000  180.00000    1.000000    5.000000    5.000000
# 25%      199.7500  184.750000  330.00000   50.000000   55.000000   50.000000
# 50%      399.5000  364.500000  450.00000   65.000000   75.000000   70.000000
# 75%      599.2500  539.250000  515.00000   80.000000  100.000000   90.000000
# max      799.0000  721.000000  780.00000  255.000000  190.000000  230.000000
#
#           Sp. Atk     Sp. Def       Speed  Generation
# count  800.000000  800.000000  800.000000   800.00000
# mean    72.820000   71.902500   68.277500     3.32375
# std     32.722294   27.828916   29.060474     1.66129
# min     10.000000   20.000000    5.000000     1.00000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  800 non-null    int64
#  1   #           800 non-null    int64
#  2   Name        800 non-null    object
#  3   Type 1      800 non-null    object
#  4   Type 2      414 non-null    object
#  5   Total       800 non-null    int64
#  6   HP          800 non-null    int64
#  7   Attack      800 non-null    int64
#  8   Defense     800 non-null    int64
#  9   Sp. Atk     800 non-null    int64
#  10  Sp. Def     800 non-null    int64
#  11  Speed       800 non-null    int64
#  12  Generation  800 non-null    int64
#  13  Legendary   800 non-null    bool
# dtypes: bool(1), int64(10), object(3)
# memory usage: 82.2+ KB

# %%
df.sort_values(['Type 1','HP'],ascending = [1,0])
# Out:
#      Unnamed: 0    #                     Name Type 1    Type 2  Total  HP  \
# 520         520  469                  Yanmega    Bug    Flying    515  86
# 698         698  637                Volcarona    Bug      Fire    550  85
# 231         231  214                Heracross    Bug  Fighting    500  80
# 232         232  214  HeracrossMega Heracross    Bug  Fighting    600  80
# 678         678  617                 Accelgor    Bug       NaN    495  80
# ..          ...  ...                      ...    ...       ...    ...  ..
# 106         106   98                   Krabby  Water       NaN    325  30
# 125         125  116                   Horsea  Water       NaN    295  30
# 129         129  120                   Staryu  Water       NaN    340  30
# 139         139  129                 Magikarp  Water       NaN    200  20
# 381         381  349                   Feebas  Water       NaN    200  20
#
#      Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# # Manipulation of data

# %%
df['Total Power'] = df['HP'] + df['Attack'] + df['Defense'] + df['Sp. Atk'] + df['Sp. Def'] + df['Speed']
df
# Out:
#      Unnamed: 0    #                   Name   Type 1  Type 2  Total  HP  \
# 0             0    1              Bulbasaur    Grass  Poison    318  45
# 1             1    2                Ivysaur    Grass  Poison    405  60
# 2             2    3               Venusaur    Grass  Poison    525  80
# 3             3    3  VenusaurMega Venusaur    Grass  Poison    625  80
# 4             4    4             Charmander     Fire     NaN    309  39
# ..          ...  ...                    ...      ...     ...    ...  ..
# 795         795  719                Diancie     Rock   Fairy    600  50
# 796         796  719    DiancieMega Diancie     Rock   Fairy    700  50
# 797         797  720    HoopaHoopa Confined  Psychic   Ghost    600  80
# 798         798  720     HoopaHoopa Unbound  Psychic    Dark    680  80
# 799         799  721              Volcanion     Fire   Water    600  80
#
#      Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary  \
# ...

# %%
df.drop(columns=['Total Power'],inplace = True)
df
# Out:
#      Unnamed: 0    #                   Name   Type 1  Type 2  Total  HP  \
# 0             0    1              Bulbasaur    Grass  Poison    318  45
# 1             1    2                Ivysaur    Grass  Poison    405  60
# 2             2    3               Venusaur    Grass  Poison    525  80
# 3             3    3  VenusaurMega Venusaur    Grass  Poison    625  80
# 4             4    4             Charmander     Fire     NaN    309  39
# ..          ...  ...                    ...      ...     ...    ...  ..
# 795         795  719                Diancie     Rock   Fairy    600  50
# 796         796  719    DiancieMega Diancie     Rock   Fairy    700  50
# 797         797  720    HoopaHoopa Confined  Psychic   Ghost    600  80
# 798         798  720     HoopaHoopa Unbound  Psychic    Dark    680  80
# 799         799  721              Volcanion     Fire   Water    600  80
#
#      Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df['Total'] = df.iloc[:,4:10].sum(axis=1) 
df.head(5)
# Out:
# C:\Users\hites\AppData\Local\Temp\ipykernel_17584\122750071.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df['Total'] = df.iloc[:,4:10].sum(axis=1)
#    Unnamed: 0  #                   Name Type 1  Type 2  Total  HP  Attack  \
# 0           0  1              Bulbasaur  Grass  Poison    526  45      49
# 1           1  2                Ivysaur  Grass  Poison    670  60      62
# 2           2  3               Venusaur  Grass  Poison    870  80      82
# 3           3  3  VenusaurMega Venusaur  Grass  Poison   1050  80     100
# 4           4  4             Charmander   Fire     NaN    503  39      52
#
#    Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       49       65       65     45           1      False
# 1       63       80       80     60           1      False
# ...

# %%
df[['Name','Total']]
# Out:
#                       Name  Total
# 0                Bulbasaur    526
# 1                  Ivysaur    670
# 2                 Venusaur    870
# 3    VenusaurMega Venusaur   1050
# 4               Charmander    503
# ..                     ...    ...
# 795                Diancie   1000
# 796    DiancieMega Diancie   1180
# 797    HoopaHoopa Confined   1000
# 798     HoopaHoopa Unbound   1150
# 799              Volcanion   1040
#
# [800 rows x 2 columns]

# %%
cols = list(df.columns.values)
cols
# Out:
# ['Unnamed: 0',
#  '#',
#  'Name',
#  'Type 1',
#  'Type 2',
#  'Total',
#  'HP',
#  'Attack',
#  'Defense',
#  'Sp. Atk',
#  'Sp. Def',
#  'Speed',
#  'Generation',
#  'Legendary']

# %%
df = df[cols[0:4] + [cols[-1]]+ cols[4:12]]     # Changing the columns in dataframe
df.head()
# Out:
#    Unnamed: 0  #                   Name Type 1  Legendary  Type 2  Total  HP  \
# 0           0  1              Bulbasaur  Grass      False  Poison    526  45
# 1           1  2                Ivysaur  Grass      False  Poison    670  60
# 2           2  3               Venusaur  Grass      False  Poison    870  80
# 3           3  3  VenusaurMega Venusaur  Grass      False  Poison   1050  80
# 4           4  4             Charmander   Fire      False     NaN    503  39
#
#    Attack  Defense  Sp. Atk  Sp. Def  Speed
# 0      49       49       65       65     45
# 1      62       63       80       80     60
# 2      82       83      100      100     80
# 3     100      123      122      120     80
# 4      52       43       60       50     65

# %% [markdown]
# # Exporting the output data into desired format

# %% [markdown]
# df.to_csv("Pokemon_output.csv")
# df.to_excel("")
# df.to_csv("",delimeter="\t")

# %% [markdown]
# # Filtering Data

# %%
new_df = df.loc[(df['Type 1']=="Grass") & (df['Type 2']=='Poison') 
                & (df['HP'] >= 70)]
new_df.reset_index(drop = True , inplace = True)
new_df
# Out:
#    Unnamed: 0    #                   Name Type 1  Legendary  Type 2  Total  \
# 0           2    3               Venusaur  Grass      False  Poison    870
# 1           3    3  VenusaurMega Venusaur  Grass      False  Poison   1050
# 2          50   45              Vileplume  Grass      False  Poison    840
# 3          77   71             Victreebel  Grass      False  Poison    840
# 4         652  591              Amoonguss  Grass      False  Poison    818
#
#     HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# 0   80      82       83      100      100     80
# 1   80     100      123      122      120     80
# 2   75      80       85      110       90     50
# 3   80     105       65      100       70     70
# 4  114      85       70       85       80     30

# %%
import re
df.loc[df['Type 1'].str.contains('fire|grass',flags = re.I,regex = True)]
# Out:
#      Unnamed: 0    #                   Name Type 1  Legendary  Type 2  Total  \
# 0             0    1              Bulbasaur  Grass      False  Poison    526
# 1             1    2                Ivysaur  Grass      False  Poison    670
# 2             2    3               Venusaur  Grass      False  Poison    870
# 3             3    3  VenusaurMega Venusaur  Grass      False  Poison   1050
# 4             4    4             Charmander   Fire      False     NaN    503
# ..          ...  ...                    ...    ...        ...     ...    ...
# 735         735  667                 Litleo   Fire      False  Normal    612
# 736         736  668                 Pyroar   Fire      False  Normal    842
# 740         740  672                 Skiddo  Grass      False     NaN    591
# 741         741  673                 Gogoat  Grass      False     NaN    913
# 799         799  721              Volcanion   Fire       True   Water   1040
#
# ...

# %%
df.loc[df['Name'].str.contains('^a[a-z]',flags = re.I , regex =True)]
# Out:
#      Unnamed: 0    #                       Name    Type 1  Legendary  Type 2  \
# 29           29   24                      Arbok    Poison      False     NaN
# 64           64   59                   Arcanine      Fire      False     NaN
# 68           68   63                       Abra   Psychic      False     NaN
# 70           70   65                   Alakazam   Psychic      False     NaN
# 71           71   65      AlakazamMega Alakazam   Psychic      False     NaN
# 153         153  142                 Aerodactyl      Rock      False  Flying
# 154         154  142  AerodactylMega Aerodactyl      Rock      False  Flying
# 156         156  144                   Articuno       Ice       True  Flying
# 182         182  168                    Ariados       Bug      False  Poison
# 195         195  181                   Ampharos  Electric      False     NaN
# 196         196  181      AmpharosMega Ampharos  Electric      False  Dragon
# ...

# %% [markdown]
# # Conditional Changes

# %%
df.loc[(df['Type 1']=="Fire") & (df['Legendary']== True)]
# Out:
#      Unnamed: 0    #                       Name Type 1  Legendary    Type 2  \
# 4             4    4                 Charmander   Fire       True       NaN
# 5             5    5                 Charmeleon   Fire       True       NaN
# 6             6    6                  Charizard   Fire       True    Flying
# 7             7    6  CharizardMega Charizard X   Fire       True    Dragon
# 8             8    6  CharizardMega Charizard Y   Fire       True    Flying
# 42           42   37                     Vulpix   Fire       True       NaN
# 43           43   38                  Ninetales   Fire       True       NaN
# 63           63   58                  Growlithe   Fire       True       NaN
# 64           64   59                   Arcanine   Fire       True       NaN
# 83           83   77                     Ponyta   Fire       True       NaN
# 84           84   78                   Rapidash   Fire       True       NaN
# ...

# %%
a=df.loc[df['HP'] > 50  ,  ['Generation','Legendary']] == 'TEST VALUE'
a
# Out:
#      Generation  Legendary
# 1          True       True
# 2          True       True
# 3          True       True
# 5          True       True
# 6          True       True
# ..          ...        ...
# 793        True       True
# 794        True       True
# 797        True       True
# 798        True       True
# 799        True       True
#
# [589 rows x 2 columns]

# %% [markdown]
#  # Groupby

# %%
df.groupby('Type 1').mean().sort_values('Defense',ascending = False)
# Out:
#           Unnamed: 0           #       Total         HP      Attack  \
# Type 1
# Steel     486.296296  442.851852  839.518519  65.222222   92.703704
# Rock      431.840909  392.727273  776.113636  65.363636   92.863636
# Dragon    521.843750  474.375000  929.187500  83.312500  112.125000
# Ground    392.312500  356.281250  748.343750  73.781250   95.750000
# Ghost     536.281250  486.500000  738.312500  64.437500   73.781250
# Water     333.312500  303.089286  724.428571  72.062500   74.151786
# Ice       465.666667  423.541667  727.166667  72.000000   72.750000
# Grass     380.414286  344.871429  709.928571  67.271429   73.214286
# Bug       368.072464  334.492754  631.376812  56.884058   70.971014
# Dark      507.387097  461.354839  745.806452  66.806452   88.387097
# Poison    278.285714  251.785714  670.321429  67.250000   74.678571
# Fire      360.942308  327.403846  769.500000  69.903846   84.769231
# Psychic   420.105263  380.807018  784.122807  70.631579   71.456140
# ...

# %%
df.groupby('Type 1').count()
# Out:
#           Unnamed: 0    #  Name  Legendary  Type 2  Total   HP  Attack  \
# Type 1
# Bug               69   69    69         69      52     69   69      69
# Dark              31   31    31         31      21     31   31      31
# Dragon            32   32    32         32      21     32   32      32
# Electric          44   44    44         44      17     44   44      44
# Fairy             17   17    17         17       2     17   17      17
# Fighting          27   27    27         27       7     27   27      27
# Fire              52   52    52         52      24     52   52      52
# Flying             4    4     4          4       2      4    4       4
# Ghost             32   32    32         32      22     32   32      32
# Grass             70   70    70         70      37     70   70      70
# Ground            32   32    32         32      19     32   32      32
# Ice               24   24    24         24      11     24   24      24
# ...

# %%
df['Count'] = 0
df.groupby(["Type 1","Type 2"]).count()['Count']
# Out:
# Type 1  Type 2
# Bug     Electric     2
#         Fighting     2
#         Fire         2
#         Flying      14
#         Ghost        1
#                     ..
# Water   Ice          3
#         Poison       3
#         Psychic      5
#         Rock         4
#         Steel        1
# Name: Count, Length: 136, dtype: int64

# %% [markdown]
# # Large Volume of Data

# %%
new_df = pd.DataFrame(columns = df.columns)
for df in pd.read_csv("pokemon.csv",chunksize =5):
    results = df.groupby(['Type 1']).count()
    new_df = pd.concat([new_df,results])
results
# Out:
#          Unnamed: 0  #  Name  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# Type 1
# Fire              1  1     1       1      1   1       1        1        1
# Psychic           2  2     2       2      2   2       2        2        2
# Rock              2  2     2       2      2   2       2        2        2
#
#          Sp. Def  Speed  Generation  Legendary
# Type 1
# Fire           1      1           1          1
# Psychic        2      2           2          2
# Rock           2      2           2          2
