# %%
# installing mlxtend
# %pip install mlxtend  --upgrade
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# Importing necessary libraries
import pandas as pd
import numpy as np

# %%
# reading csv file
df = pd.read_csv('/content/Market_Basket_Optimisation.csv',header=None)
df.head()  # head shows top 5 rows of dataset
# Out:
#               0          1           2                 3             4   \
# 0         shrimp    almonds     avocado    vegetables mix  green grapes
# 1        burgers  meatballs        eggs               NaN           NaN
# 2        chutney        NaN         NaN               NaN           NaN
# 3         turkey    avocado         NaN               NaN           NaN
# 4  mineral water       milk  energy bar  whole wheat rice     green tea
#
#                  5     6               7             8             9   \
# 0  whole weat flour  yams  cottage cheese  energy drink  tomato juice
# 1               NaN   NaN             NaN           NaN           NaN
# 2               NaN   NaN             NaN           NaN           NaN
# 3               NaN   NaN             NaN           NaN           NaN
# 4               NaN   NaN             NaN           NaN           NaN
#
#                10         11     12     13             14      15  \
# ...

# %%
# shape of the dataset
df.shape
# Out:
# (7501, 20)

# %%
# description of the data
df.describe()
# Out:
#                    0              1              2              3          4   \
# count            7501           5747           4389           3345       2529
# unique            115            117            115            114        110
# top     mineral water  mineral water  mineral water  mineral water  green tea
# freq              577            484            375            201        153
#
#                   5          6          7          8          9   \
# count           1864       1369        981        654        395
# unique           106        102         98         88         80
# top     french fries  green tea  green tea  green tea  green tea
# freq             107         96         67         57         31
#
#                     10         11         12         13         14      15  \
# count              256        154         87         47         25       8
# unique              66         50         43         28         19       8
# ...

# %%
transaction = []
for i in range(0, df.shape[0]):
  for j in range(0, df.shape[1]):
    transaction.append(df.values[i,j])
transaction = np.array(transaction)

# %% [markdown]
# Observations -
#
# 1.    Created a empty list
# 2.   Took Dataset into range with changing their shape
# 3.   Appending Values into list
# 4.   Storing array data into transaction

# %%
df = pd.DataFrame(transaction, columns=['items'])
df["incident_count"]= 1
indexNames = df[df['items']== "nan"].index
df.drop(indexNames ,inplace=True)

# %% [markdown]
# Observations -
#
#
# 1.   Converting array into dataframe
# 2.   Dropping values if incident_count is 1

# %%
transaction = []
for i in range(df.shape[0]):
 transaction.append([str(df.values[i,j])
  for j in range(df.shape[1])])
transaction = np.array(transaction)
from mlxtend.preprocessing import TransactionEncoder
te = TransactionEncoder()
te_ary = te.fit(transaction).transform(transaction)
df = pd.DataFrame(te_ary,columns = te.columns_)
df.head()
# Out:
#     asparagus     1  almonds  antioxydant juice  asparagus  avocado  \
# 0       False  True    False              False      False    False
# 1       False  True     True              False      False    False
# 2       False  True    False              False      False     True
# 3       False  True    False              False      False    False
# 4       False  True    False              False      False    False
#
#    babies food  bacon  barbecue sauce  black tea  ...  turkey  vegetables mix  \
# 0        False  False           False      False  ...   False           False
# 1        False  False           False      False  ...   False           False
# 2        False  False           False      False  ...   False           False
# 3        False  False           False      False  ...   False            True
# 4        False  False           False      False  ...   False           False
#
#    water spray  white wine  whole weat flour  whole wheat pasta  \
# ...

# %% [markdown]
# Observations -
#
#
# 1.   Importing Transaction Encoder from mlxtend.preprocessing
# 2.  Fitting and Transforming values into transaction
# 3.  Creating dataframe and printing top 5 rows of dataframe

# %%
from mlxtend.frequent_patterns import fpgrowth
res=fpgrowth(df,min_support = 0.05, use_colnames=True)
res.head(10)
# Out:
#     support            itemsets
# 0  1.000000                 (1)
# 1  0.060893     (mineral water)
# 2  0.060893  (mineral water, 1)

# %% [markdown]
# Observations -
#
#
# 1.    Imported fpgrwoth from mlxtend.frequent_patterns
# 2.   Created 'res' variable and created alloted him fpgrowth with data , min_support with 0.05.
# 3.   Printing top 10 rows of the dataset.

# %%
from mlxtend.frequent_patterns import association_rules
res = association_rules(res, metric='confidence',min_threshold=0.06)
res
# Out:
#        antecedents      consequents  antecedent support  consequent support  \
# 0  (mineral water)              (1)            0.060893            1.000000
# 1              (1)  (mineral water)            1.000000            0.060893
#
#     support  confidence  lift  leverage  conviction
# 0  0.060893    1.000000   1.0       0.0         inf
# 1  0.060893    0.060893   1.0       0.0         1.0

# %% [markdown]
# Observations -
#
#
# 1.   Imported Association_rules from mlxtend.frequent_patterns
# 2.   Created Association Rules function with min_threshold =  0.06  and metric = 'confidence'
# 3.  In Output, we found associaton rule for mineral water

# %%
from google.colab import files
df.to_csv('output.csv', encoding = 'utf-8-sig')
files.download('output.csv')
